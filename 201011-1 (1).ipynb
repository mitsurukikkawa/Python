# %%
from gensim.models.doc2vec import Doc2Vec
model = Doc2Vec.load("jawiki.doc2vec.dbow300d/jawiki.doc2vec.dbow300d.model")

# %%
import MeCab

def tokenize(text):
    wakati = MeCab.Tagger("-O wakati")
    wakati.parse("")
    return wakati.parse(text).strip().split()

# %%
# ファイル読み込み
f=open('canon2016.txt','r')
text=f.read()
f.close()

# 空行の削除
text = re.sub('\n\n', '\n', text)

print(text)
# Out:
# ３【対処すべき課題】
#   2017年の世界経済は、IMFの予測によれば、緩やかに持ち直すことが期待されていますが、引き続き政治経済の不確実性が高い状況となるものと見込まれます。
#   当社関連市場においては、オフィス向け複合機の需要は、モノクロ機の縮小をカラー機が補い、全体としてはほぼ前年並みで推移する見通しです。レーザープリンターの需要も、ほぼ前年並みの水準が見込まれますが、消耗品の販売が期待できるカラー機やレーザー複合機の需要は拡大する見通しです。レンズ交換式デジタルカメラの需要は、先進国を中心に減少が続いていますが、そのマイナス幅は縮小し、底入れに向かう見通しです。コンパクトデジタルカメラは、低価格モデルを中心に引き続き市場の縮小が続く見通しです。インクジェットプリンターの需要も、コンシューマ向けを中心に引き続き縮小傾向が続くものと見込んでおります。一方、産業機器では、半導体露光装置はほぼ前年並みの市場規模となる見込みですが、FPD露光装置・有機ELディスプレイ製造装置については、パネルメーカーの活発な設備投資が継続し、市場が拡大する見通しです。ネットワークカメラについても、災害監視や犯罪防止を目的とした利用に加え、マーケティングや生産現場の効率化への活用ニーズも高まっており、市場の拡大が続く見込みです。
#   このような状況の中、「グローバル優良企業グループ構想フェーズⅤ」の２年目である2017年は当社創立80周年に当りますが、節目にふさわしい年とすべく、「改革を加速し、戦略的大転換を強力に推進する」をテーマに、以下の重点施策に取り組んでまいります。
# 1.現行事業の徹底強化
#   事業構造の転換を成功させるため、それを支える現行事業を再強化し収益性を向上することに努めます。具体的には、他社には真似のできないような魅力や強みにより高い利益率を実現する「ダントツ商品」の開発を加速するとともに、自動化、内製化、調達革新などの諸施策を進化させ、より一層の原価低減を図ることで、売上高原価率45％の達成を目指します。また、IoTとクラウド環境に対応した新しいビジネスモデルを開発し、事業領域の拡大を図ります。
# 2.新規事業の強化拡大と将来事業の創出
# ...

# %%
import re
#canon
canon2016=open('canon2016.txt','r').read()
canon2016 = re.sub('\n\n', '\n', canon2016)
canon2016 = canon2016.split()

canon2017=open('canon2017.txt','r').read()
canon2017 = re.sub('\n\n', '\n', canon2017)
canon2017 = canon2017.split()

canon2018=open('canon2018.txt','r').read()
canon2018 = re.sub('\n\n', '\n', canon2018)
canon2018 = canon2018.split()

canon2019=open('canon2019.txt','r').read()
canon2019 = re.sub('\n\n', '\n', canon2019)
canon2019 = canon2019.split()

#fujitsu
fujitsu2016=open('fujitsu2016.txt','r').read()
fujitsu2016 = re.sub('\n\n', '\n', fujitsu2016)
fujitsu2016 = fujitsu2016.split()

fujitsu2017=open('fujitsu2017.txt','r').read()
fujitsu2017 = re.sub('\n\n', '\n', fujitsu2017)
fujitsu2017 = fujitsu2017.split()

fujitsu2018=open('fujitsu2018.txt','r').read()
fujitsu2018 = re.sub('\n\n', '\n', fujitsu2018)
fujitsu2018 = fujitsu2018.split()

fujitsu2019=open('fujitsu2019.txt','r').read()
fujitsu2019 = re.sub('\n\n', '\n', fujitsu2019)
fujitsu2019 = fujitsu2019.split()

#hitachi
hitachi2016=open('hitachi2016.txt','r').read()
hitachi2016 = re.sub('\n\n', '\n', hitachi2016)
hitachi2016 = hitachi2016.split()

hitachi2017=open('hitachi2017.txt','r').read()
hitachi2017 = re.sub('\n\n', '\n', hitachi2017)
hitachi2017 = hitachi2017.split()

hitachi2018=open('hitachi2018.txt','r').read()
hitachi2018 = re.sub('\n\n', '\n', hitachi2018)
hitachi2018 = hitachi2018.split()

hitachi2019=open('hitachi2019.txt','r').read()
hitachi2019 = re.sub('\n\n', '\n', hitachi2019)
hitachi2019 = hitachi2019.split()

#mitsubishi
mitsubishi2016=open('mitsubishi2016.txt','r').read()
mitsubishi2016 = re.sub('\n\n', '\n', mitsubishi2016)
mitsubishi2016 = mitsubishi2016.split()

mitsubishi2017=open('mitsubishi2017.txt','r').read()
mitsubishi2017 = re.sub('\n\n', '\n', mitsubishi2017)
mitsubishi2017 = mitsubishi2017.split()

mitsubishi2018=open('mitsubishi2018.txt','r').read()
mitsubishi2018 = re.sub('\n\n', '\n', mitsubishi2018)
mitsubishi2018 = mitsubishi2018.split()

mitsubishi2019=open('mitsubishi2019.txt','r').read()
mitsubishi2019 = re.sub('\n\n', '\n', mitsubishi2019)
mitsubishi2019 = mitsubishi2019.split()

#nec
nec2016=open('nec2016.txt','r').read()
nec2016 = re.sub('\n\n', '\n', nec2016)
nec2016 = nec2016.split()

nec2017=open('nec2017.txt','r').read()
nec2017 = re.sub('\n\n', '\n', nec2017)
nec2017 = nec2017.split()

nec2018=open('nec2018.txt','r').read()
nec2018 = re.sub('\n\n', '\n', nec2018)
nec2018 = nec2018.split()

nec2019=open('nec2019.txt','r').read()
nec2019 = re.sub('\n\n', '\n', nec2019)
nec2019 = nec2019.split()

#nidec
nidec2016=open('nidec2016.txt','r').read()
nidec2016 = re.sub('\n\n', '\n', nidec2016)
nidec2016 = nidec2016.split()

nidec2017=open('nidec2017.txt','r').read()
nidec2017 = re.sub('\n\n', '\n', nidec2017)
nidec2017 = nidec2017.split()

nidec2018=open('nidec2018.txt','r').read()
nidec2018 = re.sub('\n\n', '\n', nidec2018)
nidec2018 = nidec2018.split()

nidec2019=open('nidec2019.txt','r').read()
nidec2019 = re.sub('\n\n', '\n', nidec2019)
nidec2019 = nidec2019.split()

#panasonic
panasonic2016=open('panasonic2016.txt','r').read()
panasonic2016 = re.sub('\n\n', '\n', panasonic2016)
panasonic2016 = panasonic2016.split()

panasonic2017=open('panasonic2017.txt','r').read()
panasonic2017 = re.sub('\n\n', '\n', panasonic2017)
panasonic2017 = panasonic2017.split()

panasonic2018=open('panasonic2018.txt','r').read()
panasonic2018 = re.sub('\n\n', '\n', panasonic2018)
panasonic2018 = panasonic2018.split()

panasonic2019=open('panasonic2019.txt','r').read()
panasonic2019 = re.sub('\n\n', '\n', panasonic2019)
panasonic2019 = panasonic2019.split()

#richo
richo2016=open('richo2016.txt','r').read()
richo2016 = re.sub('\n\n', '\n', richo2016)
richo2016 = richo2016.split()

richo2017=open('richo2017.txt','r').read()
richo2017 = re.sub('\n\n', '\n', richo2017)
richo2017 = richo2017.split()

richo2018=open('richo2018.txt','r').read()
richo2018 = re.sub('\n\n', '\n', richo2018)
richo2018 = richo2018.split()

richo2019=open('richo2019.txt','r').read()
richo2019 = re.sub('\n\n', '\n', richo2019)
richo2019 = richo2019.split()

#sharp
sharp2016=open('sharp2016.txt','r').read()
sharp2016 = re.sub('\n\n', '\n', sharp2016)
sharp2016 = sharp2016.split()

sharp2017=open('sharp2017.txt','r').read()
sharp2017 = re.sub('\n\n', '\n', sharp2017)
sharp2017 = sharp2017.split()

sharp2018=open('sharp2018.txt','r').read()
sharp2018 = re.sub('\n\n', '\n', sharp2018)
sharp2018 = sharp2018.split()

sharp2019=open('sharp2019.txt','r').read()
sharp2019 = re.sub('\n\n', '\n', sharp2019)
sharp2019 = sharp2019.split()

#sony
sony2016=open('sony2016.txt','r').read()
sony2016 = re.sub('\n\n', '\n', sony2016)
sony2016 = sony2016.split()

sony2017=open('sony2017.txt','r').read()
sony2017 = re.sub('\n\n', '\n', sony2017)
sony2017 = sony2017.split()

sony2018=open('sony2018.txt','r').read()
sony2018 = re.sub('\n\n', '\n', sony2018)
sony2018 = sony2018.split()

sony2019=open('sony2019.txt','r').read()
sony2019 = re.sub('\n\n', '\n', sony2019)
sony2019 = sony2019.split()

#toshiba
toshiba2016=open('toshiba2016.txt','r').read()
toshiba2016 = re.sub('\n\n', '\n', toshiba2016)
toshiba2016 = toshiba2016.split()

toshiba2017=open('toshiba2017.txt','r').read()
toshiba2017 = re.sub('\n\n', '\n', toshiba2017)
toshiba2017 = toshiba2017.split()

toshiba2018=open('toshiba2018.txt','r').read()
toshiba2018 = re.sub('\n\n', '\n', toshiba2018)
toshiba2018 = toshiba2018.split()

toshiba2019=open('toshiba2019.txt','r').read()
toshiba2019 = re.sub('\n\n', '\n', toshiba2019)
toshiba2019 = toshiba2019.split()

# %%
#canon
print(model.docvecs.similarity_unseen_docs(model,canon2016,canon2017))
print(model.docvecs.similarity_unseen_docs(model,canon2017,canon2018))
print(model.docvecs.similarity_unseen_docs(model,canon2018,canon2019))

#fujitsu
print(model.docvecs.similarity_unseen_docs(model,fujitsu2016,fujitsu2017))
print(model.docvecs.similarity_unseen_docs(model,fujitsu2017,fujitsu2018))
print(model.docvecs.similarity_unseen_docs(model,fujitsu2018,fujitsu2019))

#hitachi
print(model.docvecs.similarity_unseen_docs(model,hitachi2016,hitachi2017))
print(model.docvecs.similarity_unseen_docs(model,hitachi2017,hitachi2018))
print(model.docvecs.similarity_unseen_docs(model,hitachi2018,hitachi2019))

#mitsubishi
print(model.docvecs.similarity_unseen_docs(model,mitsubishi2016,mitsubishi2017))
print(model.docvecs.similarity_unseen_docs(model,mitsubishi2017,mitsubishi2018))
print(model.docvecs.similarity_unseen_docs(model,mitsubishi2018,mitsubishi2019))

#nec
print(model.docvecs.similarity_unseen_docs(model,nec2016,nec2017))
print(model.docvecs.similarity_unseen_docs(model,nec2017,nec2018))
print(model.docvecs.similarity_unseen_docs(model,nec2018,nec2019))

#nidec
print(model.docvecs.similarity_unseen_docs(model,nidec2016,nidec2017))
print(model.docvecs.similarity_unseen_docs(model,nidec2017,nidec2018))
print(model.docvecs.similarity_unseen_docs(model,nidec2018,nidec2019))

#panasonic
print(model.docvecs.similarity_unseen_docs(model,panasonic2016,panasonic2017))
print(model.docvecs.similarity_unseen_docs(model,panasonic2017,panasonic2018))
print(model.docvecs.similarity_unseen_docs(model,panasonic2018,panasonic2019))

#richo
print(model.docvecs.similarity_unseen_docs(model,richo2016,richo2017))
print(model.docvecs.similarity_unseen_docs(model,richo2017,richo2018))
print(model.docvecs.similarity_unseen_docs(model,richo2018,richo2019))

#sharp
print(model.docvecs.similarity_unseen_docs(model,sharp2016,sharp2017))
print(model.docvecs.similarity_unseen_docs(model,sharp2017,sharp2018))
print(model.docvecs.similarity_unseen_docs(model,sharp2018,sharp2019))

#sony
print(model.docvecs.similarity_unseen_docs(model,sony2016,sony2017))
print(model.docvecs.similarity_unseen_docs(model,sony2017,sony2018))
print(model.docvecs.similarity_unseen_docs(model,sony2018,sony2019))

#toshiba
print(model.docvecs.similarity_unseen_docs(model,toshiba2016,toshiba2017))
print(model.docvecs.similarity_unseen_docs(model,toshiba2017,toshiba2018))
print(model.docvecs.similarity_unseen_docs(model,toshiba2018,toshiba2019))
# Out:
# 0.012900717
# -0.12929034
# -0.01842276
# 0.8768783
# 0.93901175
# 0.9201624
# 0.0013532276
# -0.04441703
# -0.016713586
# 0.924091
# 0.97024727
# 0.7883278
# 0.8144839
# 0.7304382
# 0.8323612
# 0.7336007
# 0.4896883
# -0.07241131
# 0.9762394
# 0.92104524
# 0.92882526
# 0.72298336
# 0.70840526
# 0.7470935
# 0.70952874
# 0.9038131
# 0.4317364
# 0.76330775
# 0.91263855
# 0.8517561
# 0.7535392
# 0.8019941
# 0.009446076

# %%
model.wv.most_similar("キャノン", topn=3)
# Out:
# [('ビーム', 0.7685264348983765),
#  ('キャノン砲', 0.7481173872947693),
#  ('ビームキャノン', 0.7351151704788208)]

# %%
s1 = 'i love you .'
doc_words1 = s1.split()

# %%
doc_words1
# Out:
# ['i', 'love', 'you', '.']

# %%
s1
# Out:
# 'i love you .'
